# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np
from scipy.stats import norm

# %%
column_names = ['vel', 'channel', 'random']
df =pd.read_csv('stopping_power-100.csv')

# %%
 fig, ax = plt.subplots(figsize=(6, 4))

ax.scatter(y=df['stopping'], x=df['velocity'], marker='x', color='mediumblue', label='Channel Points')

#ch, = ax.plot(df['velocity'], df['stopping'], color='mediumblue', label='Channel Line')

ax.set_ylabel('Stopping Power')
ax.set_xlabel('Velocity')
#ax.set_title('Single Precision')

#l1 = ax.legend((ch, och), ('channel', 'Random'), loc=(0.12, 0.02), ncol=2, fontsize=8)
#ax.add_artist(l1)

ax.legend()
plt.show()

#fig.tight_layout()
#fig.savefig(os.path.join('graph-images', 'test1.png'), dpi=320)

# %%
 fig, ax = plt.subplots(figsize=(6, 4))

ax.scatter(y=df_2['channel'], x=df_2['vel'], marker='x', color='mediumblue', label='Channel Points')
ax.scatter(y=df_2['random'], x=df_2['vel'], marker='x', color='crimson', label='Random Points')

ch, = ax.plot(df_2['vel'], df_2['channel'], color='mediumblue', label='Channel Line')
och, = ax.plot(df_2['vel'], df_2['random'], color='crimson', linestyle='--', label='Random Line')

ax.set_ylabel('Channel/Random')
ax.set_xlabel('Velocity')
ax.set_title('Double Precision')

#l1 = ax.legend((ch, och), ('channel', 'Random'), loc=(0.12, 0.02), ncol=2, fontsize=8)
#ax.add_artist(l1)
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 5))

ax.scatter(y=df['channel'], x=df['vel'], marker='x', color='mediumblue', label='Channel_single Points')
ax.scatter(y=df['random'], x=df['vel'], marker='x', color='crimson', label='Random_single Points')

ax.scatter(y=df_2['channel'], x=df_2['vel'], marker='x', color='purple', label='Channel_double Points')
ax.scatter(y=df_2['random'], x=df_2['vel'], marker='x', color='green', label='Random_double Points')

ax.plot(df['vel'], df['channel'], color='mediumblue', label='Channel_single Line')
ax.plot(df['vel'], df['random'], color='crimson', linestyle='--', label='Random_single Line')

ax.plot(df_2['vel'], df_2['channel'], color='purple', label='Channel_double Line')
ax.plot(df_2['vel'], df_2['random'], color='green', linestyle='--', label='Random_double Line')

ax.set_ylabel('Channel/Random')
ax.set_xlabel('Velocity')
ax.set_title('Single Precision and Double Precision')

#l1 = ax.legend((ch, och), ('channel', 'Random'), loc=(0.12, 0.02), ncol=2, fontsize=8)
#ax.add_artist(l1)
fig.savefig(os.path.join('graph-images', 'ds.png'), dpi=320)

ax.legend()
plt.show()

# %%
#x = np.arange((-3, 3, 0.01))
#plt.plot(x, norm.pdf(x))
#plt.show()
np.arange?
# Out:
# Docstring:
# arange([start,] stop[, step,], dtype=None, *, like=None)
#
# Return evenly spaced values within a given interval.
#
# ``arange`` can be called with a varying number of positional arguments:
#
# * ``arange(stop)``: Values are generated within the half-open interval
#   ``[0, stop)`` (in other words, the interval including `start` but
#   excluding `stop`).
# * ``arange(start, stop)``: Values are generated within the half-open
#   interval ``[start, stop)``.
# * ``arange(start, stop, step)`` Values are generated within the half-open
#   interval ``[start, stop)``, with spacing between values given by
#   ``step``.
#
# For integer arguments the function is roughly equivalent to the Python
# built-in :py:class:`range`, but returns an ndarray rather than a ``range``
# instance.
#
# When using a non-integer step, such as 0.1, it is often better to use
# `numpy.linspace`.
#
# See the Warning sections below for more information.
#
# Parameters
# ----------
# ...
